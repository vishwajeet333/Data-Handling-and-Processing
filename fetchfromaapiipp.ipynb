# %%
import pandas as pd
import requests

# %% [markdown]
# ### API KEY -> https://www.themoviedb.org/settings/api

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e7beb8de4804a62e5e5c9098938506d4&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 30.8191,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.716,
#    'vote_count': 29719},
#   {'adult': False,
#    'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 30.8191,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.716,
#   'vote_count': 29719},
#  {'adult': False,
#   'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head(2)
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     30.8191
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     36.4215
#
#    vote_average  vote_count
# 0         8.716       29719
# 1         8.687       22450

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1, 534):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e7beb8de4804a62e5e5c9098938506d4&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 3
#       1 for i in range (1, 534):
#       2     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e7beb8de4804a62e5e5c9098938506d4&language=en-US&page={}'.format(i))
# ----> 3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#       4     df = pd.concat([df, temp_df], ignore_index = True)
#
# KeyError: 'results'

# %%
df
# Out:
#            id                         title  \
# 0      505063    Await Further Instructions
# 1       73861                A Serbian Film
# 2       38317                     Zookeeper
# 3        2157                 Lost in Space
# 4      182219               Serial Teachers
# ...       ...                           ...
# 10015   10012                        Cursed
# 10016  480042   Escape Plan: The Extractors
# 10017  465086                    The Grudge
# 10018  276839               Home Sweet Hell
# 10019   39346  Casper: A Spirited Beginning
#
#                                                 overview release_date  \
# 0      A dysfunctional family awake on Christmas morn...   2018-08-26
# 1      Retired porn star Milos leads a normal family ...   2010-01-06
# 2      Kindhearted Griffin Keyes is one of the best-l...   2011-07-06
# 3      The prospects for continuing life on Earth in ...   1998-04-03
# 4      With only 12 percent of its pupils obtaining t...   2013-04-17
# ...

# %%
df.shape
# Out:
# (10020, 7)

# %%
df.to_csv('movies.csv')
